# %%
#imports
import pandas as pd
import time
from pathlib import Path
from datetime import datetime
import sqlite3

# %%
# build db conection
price =  Path("../Resources/inventory.db")
con = sqlite3.connect(price)
cur = con.cursor()
dbtable = "VOW"

# %%
# load table as pandas pd
db_df = pd.read_sql_query(f"SELECT * FROM '{dbtable}'", con)
db_df
# Out:
#     setCode                   name    rarity   manaCost colorIdentity  \
# 0       VOW           Adamant Will    common     {1}{W}             W
# 1       VOW  Angelic Quartermaster  uncommon  {3}{W}{W}             W
# 2       VOW        Arm the Cathars  uncommon  {1}{W}{W}             W
# 3       VOW           Bride's Gown  uncommon     {1}{W}             W
# 4       VOW     By Invitation Only      rare  {3}{W}{W}             W
# ..      ...                    ...       ...        ...           ...
# 279     VOW      Welcoming Vampire      rare     {2}{W}             W
# 280     VOW                 Island    common          0             U
# 281     VOW                  Swamp    common          0             B
# 282     VOW               Mountain    common          0             R
# 283     VOW                 Forest    common          0             G
#
#         types        subtypes  power  toughness  quantity     nm  lp  p  foil  \
# 0     Instant               0      0          0     10293  10290   3  0     0
# 1    Creature  Angel, Soldier      3          3         0      0   0  0     0
# 2     Sorcery               0      0          0         0      0   0  0     0
# 3    Artifact       Equipment      0          0         3      2   1  0     0
# 4     Sorcery               0      0          0         0      0   0  0     0
# ..        ...             ...    ...        ...       ...    ...  .. ..   ...
# 279  Creature         Vampire      2          3         0      0   0  0     0
# 280      Land          Island      0          0         0      0   0  0     0
# 281      Land           Swamp      0          0         0      0   0  0     0
# 282      Land        Mountain      0          0         0      0   0  0     0
# 283      Land          Forest      0          0         0      0   0  0     0
#
#                                                   text MktPrice
# 0    Target creature gets +2/+2 and gains indestruc...    $0.02
# 1    Flying\nWhen Angelic Quartermaster enters the ...    $0.03
# 2    Until end of turn, target creature gets +3/+3,...    $0.01
# 3    Equipped creature gets +2/+0. It gets an addit...    $0.03
# 4    Choose a number between 0 and 13. Each player ...    $0.30
# ..                                                 ...      ...
# 279  Flying\nWhenever one or more other creatures w...    $2.22
# 280                                    ({T}: Add {U}.)     None
# 281                                    ({T}: Add {B}.)     None
# 282                                    ({T}: Add {R}.)     None
# 283                                    ({T}: Add {G}.)     None
#
# [284 rows x 16 columns]

# %%
# calculate total inventory price

# %%
# show result

# %%
# save result to price db with date
