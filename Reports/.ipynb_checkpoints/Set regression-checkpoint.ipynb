# %%
#imports
#imports
import pandas as pd
import time
from pathlib import Path
from datetime import datetime
import sqlite3
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
#dbtable = ['innistrad-midnight-hunt', '10th-edition', 'the-brothers-war', 'dragons-maze', 'dominaria-united', 'throne-of-eldraine', 'gatecrash', 'march-of-the-machine-the-aftermath', 'march-of-the-machine', 'kamigawa-neon-dynasty', 'phyrexia-all-will-be-one', 'return-to-ravnica', 'streets-of-new-capenna', 'innistrad-crimson-vow', 'wilds-of-eldraine']
dbtable = 'dominaria-united'

# %%
# build conection to price db
price =  Path("../Resources/price.db")
con = sqlite3.connect(price)
cur = con.cursor()

# %%
# import set data as pd df
db_df = pd.read_sql_query(f"SELECT * FROM '{dbtable}_priceData'", con)
db_df
# Out:
#      Unnamed: 0                                         Name Market Price  \
# 0             2                           Academy Loremaster        $0.11
# 1             2            Academy Loremaster (Extended Art)        $0.21
# 2             2                                 Academy Wall        $0.01
# 3             2                               Adarkar Wastes        $4.96
# 4             2                  Adarkar Wastes (Borderless)        $4.62
# ..          ...                                          ...          ...
# 503           2       Zar Ojanen, Scion of Efrava (Showcase)        $0.04
# 504           2  Zar Ojanen, Scion of Efrava (Textured Foil)        $0.06
# 505           2                         Zur, Eternal Schemer        $1.01
# 506           2              Zur, Eternal Schemer (Showcase)        $0.36
# 507           2         Zur, Eternal Schemer (Textured Foil)        $1.97
#
#            date
# 0    2023-11-28
# 1    2023-11-28
# 2    2023-11-28
# 3    2023-11-28
# 4    2023-11-28
# ..          ...
# 503  2023-11-28
# 504  2023-11-28
# 505  2023-11-28
# 506  2023-11-28
# 507  2023-11-28
#
# [508 rows x 4 columns]

# %%
setplist= []
date_list = list(db_df['date'].unique())
#print(date_list[1])

# %%
#day_df= db_df.loc[db_df["date"]== date_list[1]]
#day_df = day_df.reset_index(drop=True)
#day_df

# %%
for x in date_list:
    day_df= db_df.loc[db_df["date"]== x ]
    day_df = day_df.reset_index(drop=True)
    for i in  range(len(day_df)):
        x = day_df.loc[i,['Market Price']] 
        x = x['Market Price']
        x = x.replace("$", "")
        x = x.replace("None", "")
        day_df['Market Price'][i] = x
    day_df['Market Price'] = pd.to_numeric(day_df['Market Price'])
    set_price = day_df['Market Price'].sum()
    setplist.append(set_price)
print(set_price)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# ...
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\pc\AppData\Local\Temp\ipykernel_9972\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x

# %%
print(setplist)
# Out:
# [628.45]

# %%
sip_list= zip(setplist, date_list)
mkt_df = pd.DataFrame(sip_list,columns = ['price', 'date'])
mkt_df['date'] = pd.to_datetime(mkt_df['date'])
mkt_df['Date Numeric'] = pd.to_numeric(mkt_df['date'])
mkt_df["price"] = pd.to_numeric(mkt_df["price"])
mkt_df
# Out:
#     price       date         Date Numeric
# 0  628.45 2023-11-28  1701129600000000000

# %%
# plot line graph
plt.plot(mkt_df['date'], mkt_df['price'], color='red', label= dbtable)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# calculate regresion
slope, intercept, r, p, se  = linregress(mkt_df['price'], mkt_df['Date Numeric'])
print(r)
print(slope)
# Out:
# 0.0
# nan
# C:\Users\pc\anaconda3\Lib\site-packages\scipy\stats\_stats_mstats_common.py:182: RuntimeWarning: invalid value encountered in scalar divide
#   slope = ssxym / ssxm
# C:\Users\pc\anaconda3\Lib\site-packages\scipy\stats\_stats_mstats_common.py:196: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# C:\Users\pc\anaconda3\Lib\site-packages\scipy\stats\_stats_mstats_common.py:199: RuntimeWarning: invalid value encountered in scalar divide
#   slope_stderr = np.sqrt((1 - r**2) * ssym / ssxm / df)

# %%
# show/ save regresion value

# %%
# save to a regresion table
