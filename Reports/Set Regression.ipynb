# %%
#imports
#imports
import pandas as pd
import time
from pathlib import Path
from datetime import datetime
import sqlite3
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
#dbtable = ['innistrad-midnight-hunt', '10th-edition', 'the-brothers-war', 'dragons-maze', 'dominaria-united', 'throne-of-eldraine', 'gatecrash', 'march-of-the-machine-the-aftermath', 'march-of-the-machine', 'kamigawa-neon-dynasty', 'phyrexia-all-will-be-one', 'return-to-ravnica', 'streets-of-new-capenna', 'innistrad-crimson-vow', 'wilds-of-eldraine']
dbtable = 'innistrad-midnight-hunt'

# %%
# build conection to price db
price =  Path("../Resources/price.db")
con = sqlite3.connect(price)
cur = con.cursor()

# %%
# import set data as pd df
db_df = pd.read_sql_query(f"SELECT * FROM '{dbtable}_priceData'", con)
db_df.head(3)
# Out:
#    Unnamed: 0                                    Name Market Price        date
# 0           0                        Abandon the Post        $0.02  2023-11-21
# 1           1             Adeline, Resplendent Cathar        $6.97  2023-11-21
# 2           2  Adeline, Resplendent Cathar (Showcase)        $5.80  2023-11-21

# %%
setplist= []
date_list = list(db_df['date'].unique())   # create list of unique dates

# %%
for x in date_list:
    day_df= db_df.loc[db_df["date"]== x ]   #create df of all cards on unique date
    day_df = day_df.reset_index(drop=True)  # reset date df index
    for i in  range(len(day_df)):
        x = day_df.loc[i,['Market Price']] 
        x = x['Market Price']      # clean data
        x = x.replace("$", "")
        x = x.replace("None", "")
        day_df['Market Price'][i] = x
    day_df['Market Price'] = pd.to_numeric(day_df['Market Price'])
    set_price = day_df['Market Price'].sum()
    setplist.append(set_price)                # appened total price for day to list
print(set_price)
# Out:
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# ...
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x
# C:\Users\fumev\AppData\Local\Temp\ipykernel_20700\4221786325.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_df['Market Price'][i] = x

# %%
# create a df of unique date, combined price of cards in set, and numeric date
sip_list= zip(setplist, date_list)
mkt_df = pd.DataFrame(sip_list,columns = ['price', 'date'])
mkt_df['date'] = pd.to_datetime(mkt_df['date'])
mkt_df['Date Numeric'] = pd.to_numeric(mkt_df['date'])
mkt_df["price"] = pd.to_numeric(mkt_df["price"])
mkt_df
# Out:
#     price       date         Date Numeric
# 0  348.08 2023-11-21  1700524800000000000
# 1  348.15 2023-11-22  1700611200000000000
# 2  357.70 2023-11-28  1701129600000000000
# 3  359.43 2023-11-29  1701216000000000000

# %%
# plot line graph
plt.plot(mkt_df['date'], mkt_df['price'], color='red', label= dbtable)
plt.savefig('..\Resources\setreg.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# calculate regresion
slope, intercept, r, p, se  = linregress(mkt_df['price'], mkt_df['Date Numeric'])
print(r)
# Out:
# 0.9953217719438755
# 57794391037511.8
