# %%
import requests
from urllib.parse import quote
import pandas as pd
from pathlib import Path
import sqlite3

# %%
sset =
urlstring =

# %%
setname = 'Dominaria United'
encoded_name = quote(setname) # Use quote if not starting with URL-encoded values
url = f"https://www.mtggoldfish.com/sets/{urlstring}#paper"
res = requests.get(url)

# %%
markup = res.text
delim =  f'var d = "Date,{sset}-main_set";'                      #'hash == "#tab-paper"'
chunks = markup.split(delim)
chunks.pop(0)
markup = ''.join(chunks)
delim = 'g = new Dygraph'
chunks = markup.split(delim)
markup = chunks.pop(0).rstrip()
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">\n<html data-skip-ads=\'false\' data-theme=\'light\' lang=\'en\' xmlns=\'http://www.w3.org/1999/xhtml\'>\n<head>\n<script async=\'\' src=\'https://www.googletagmanager.com/gtag/js?id=G-PS4ZC64YQQ\'></script>\n<script>\n  window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\n  gtag(\'js\', new Date());\n  gtag(\'config\', \'G-PS4ZC64YQQ\');\n</script>\n\n<link rel="alternate" type="application/atom+xml" title="ATOM" href="https://www.mtggoldfish.com/feed" />\n<link rel="alternate" type="application/rss+xml" title="RSS" href="https://www.mtggoldfish.com/feed.rss" />\n<link href=\'https://assets1.mtggoldfish.com/assets/goldfish-32-f20e07cb013875a224711f3121fb46fd51d56814b12216549c072fa7f8ab207d.png\' rel=\'apple-touch-icon\'>\n<link href=\'https://assets1.mtggoldfish.com/assets/goldfish-72-754524b3c41e643e2d1e625be5b7341a4ad7d1d9a533cabc5f1ef68c05177ad2.png\' r
# ...

# %%
delim = 'g = new Dygraph'
chunks = markup.split(delim)
markup = chunks.pop(0).rstrip()
#markup = ''.join(chunks).lstrip()
print(markup)
# Out:
#   d += "\n2020-12-16, 59.0";
#   d += "\n2020-12-17, 126.02";
#   d += "\n2020-12-18, 135.52";
#   d += "\n2020-12-19, 133.51";
#   d += "\n2020-12-20, 169.37";
#   d += "\n2020-12-21, 168.59";
#   d += "\n2020-12-22, 184.33";
#   d += "\n2020-12-23, 183.05";
#   d += "\n2020-12-24, 179.46";
#   d += "\n2020-12-25, 137.7";
#   d += "\n2020-12-26, 130.4";
#   d += "\n2020-12-27, 159.22";
#   d += "\n2020-12-28, 173.29";
#   d += "\n2020-12-29, 157.79";
#   d += "\n2020-12-30, 155.96";
#   d += "\n2020-12-31, 153.94";
#   d += "\n2021-01-01, 153.07";
#   d += "\n2021-01-02, 153.07";
#   d += "\n2021-01-03, 152.88";
#   d += "\n2021-01-04, 136.07";
#   d += "\n2021-01-05, 134.32";
#   d += "\n2021-01-06, 137.01";
#   d += "\n2021-01-07, 282.37";
#   d += "\n2021-01-08, 354.78";
#   d += "\n2021-01-09, 331.22";
#   d += "\n2021-01-10, 351.16";
#   d += "\n2021-01-11, 415.53";
#   d += "\n2021-01-12, 382.27";
#   d += "\n2021-01-13, 380.75";
#   d += "\n2021-01-14, 377.14";
# ...

# %%
lines = markup.splitlines()
print(lines)
# Out:
# ['', '  d += "\\n2020-12-16, 59.0";', '  d += "\\n2020-12-17, 126.02";', '  d += "\\n2020-12-18, 135.52";', '  d += "\\n2020-12-19, 133.51";', '  d += "\\n2020-12-20, 169.37";', '  d += "\\n2020-12-21, 168.59";', '  d += "\\n2020-12-22, 184.33";', '  d += "\\n2020-12-23, 183.05";', '  d += "\\n2020-12-24, 179.46";', '  d += "\\n2020-12-25, 137.7";', '  d += "\\n2020-12-26, 130.4";', '  d += "\\n2020-12-27, 159.22";', '  d += "\\n2020-12-28, 173.29";', '  d += "\\n2020-12-29, 157.79";', '  d += "\\n2020-12-30, 155.96";', '  d += "\\n2020-12-31, 153.94";', '  d += "\\n2021-01-01, 153.07";', '  d += "\\n2021-01-02, 153.07";', '  d += "\\n2021-01-03, 152.88";', '  d += "\\n2021-01-04, 136.07";', '  d += "\\n2021-01-05, 134.32";', '  d += "\\n2021-01-06, 137.01";', '  d += "\\n2021-01-07, 282.37";', '  d += "\\n2021-01-08, 354.78";', '  d += "\\n2021-01-09, 331.22";', '  d += "\\n2021-01-10, 351.16";', '  d += "\\n2021-01-11, 415.53";', '  d += "\\n2021-01-12, 382.27";', '  d += "\\n2021-
# ...

# %%
for i, line in enumerate(lines):
    lines[i] = line.strip().lstrip('d += "\\n').rstrip('";')
    csv = '\n'.join(lines)
print(csv)
# Out:
# 2020-12-16, 59.0
# 2020-12-17, 126.02
# 2020-12-18, 135.52
# 2020-12-19, 133.51
# 2020-12-20, 169.37
# 2020-12-21, 168.59
# 2020-12-22, 184.33
# 2020-12-23, 183.05
# 2020-12-24, 179.46
# 2020-12-25, 137.7
# 2020-12-26, 130.4
# 2020-12-27, 159.22
# 2020-12-28, 173.29
# 2020-12-29, 157.79
# 2020-12-30, 155.96
# 2020-12-31, 153.94
# 2021-01-01, 153.07
# 2021-01-02, 153.07
# 2021-01-03, 152.88
# 2021-01-04, 136.07
# 2021-01-05, 134.32
# 2021-01-06, 137.01
# 2021-01-07, 282.37
# 2021-01-08, 354.78
# 2021-01-09, 331.22
# 2021-01-10, 351.16
# 2021-01-11, 415.53
# 2021-01-12, 382.27
# 2021-01-13, 380.75
# 2021-01-14, 377.14
# 2021-01-15, 387.63
# 2021-01-16, 467.27
# 2021-01-17, 433.85
# 2021-01-18, 495.59
# 2021-01-19, 488.84
# 2021-01-20, 482.55
# 2021-01-21, 437.27
# 2021-01-22, 455.88
# 2021-01-23, 515.06
# 2021-01-24, 500.59
# 2021-01-25, 524.2
# 2021-01-26, 496.71
# 2021-01-27, 475.45
# 2021-01-28, 577.07
# 2021-01-29, 543.26
# 2021-01-30, 527.05
# 2021-01-31, 511.39
# ...

# %%
#lines = markup.splitlines()
lines.pop(0)
print(lines)
# Out:
# ['2020-12-16, 59.0', '2020-12-17, 126.02', '2020-12-18, 135.52', '2020-12-19, 133.51', '2020-12-20, 169.37', '2020-12-21, 168.59', '2020-12-22, 184.33', '2020-12-23, 183.05', '2020-12-24, 179.46', '2020-12-25, 137.7', '2020-12-26, 130.4', '2020-12-27, 159.22', '2020-12-28, 173.29', '2020-12-29, 157.79', '2020-12-30, 155.96', '2020-12-31, 153.94', '2021-01-01, 153.07', '2021-01-02, 153.07', '2021-01-03, 152.88', '2021-01-04, 136.07', '2021-01-05, 134.32', '2021-01-06, 137.01', '2021-01-07, 282.37', '2021-01-08, 354.78', '2021-01-09, 331.22', '2021-01-10, 351.16', '2021-01-11, 415.53', '2021-01-12, 382.27', '2021-01-13, 380.75', '2021-01-14, 377.14', '2021-01-15, 387.63', '2021-01-16, 467.27', '2021-01-17, 433.85', '2021-01-18, 495.59', '2021-01-19, 488.84', '2021-01-20, 482.55', '2021-01-21, 437.27', '2021-01-22, 455.88', '2021-01-23, 515.06', '2021-01-24, 500.59', '2021-01-25, 524.2', '2021-01-26, 496.71', '2021-01-27, 475.45', '2021-01-28, 577.07', '2021-01-29, 543.26', '2021-01-30,
# ...

# %%
df =[]
for i in lines:
    i = i.split(',')
    df.append([i[0],i[1]])
df
# Out:
# [['2020-12-16', ' 59.0'],
#  ['2020-12-17', ' 126.02'],
#  ['2020-12-18', ' 135.52'],
#  ['2020-12-19', ' 133.51'],
#  ['2020-12-20', ' 169.37'],
#  ['2020-12-21', ' 168.59'],
#  ['2020-12-22', ' 184.33'],
#  ['2020-12-23', ' 183.05'],
#  ['2020-12-24', ' 179.46'],
#  ['2020-12-25', ' 137.7'],
#  ['2020-12-26', ' 130.4'],
#  ['2020-12-27', ' 159.22'],
#  ['2020-12-28', ' 173.29'],
#  ['2020-12-29', ' 157.79'],
#  ['2020-12-30', ' 155.96'],
#  ['2020-12-31', ' 153.94'],
#  ['2021-01-01', ' 153.07'],
#  ['2021-01-02', ' 153.07'],
#  ['2021-01-03', ' 152.88'],
#  ['2021-01-04', ' 136.07'],
#  ['2021-01-05', ' 134.32'],
#  ['2021-01-06', ' 137.01'],
#  ['2021-01-07', ' 282.37'],
#  ['2021-01-08', ' 354.78'],
#  ['2021-01-09', ' 331.22'],
#  ['2021-01-10', ' 351.16'],
#  ['2021-01-11', ' 415.53'],
#  ['2021-01-12', ' 382.27'],
#  ['2021-01-13', ' 380.75'],
#  ['2021-01-14', ' 377.14'],
#  ['2021-01-15', ' 387.63'],
#  ['2021-01-16', ' 467.27'],
#  ['2021-01-17', ' 433.85'],
# ...

# %%
df = pd.DataFrame(df, columns = ['date', 'price'])

# %%
df['setcode'] = sset

# %%
df = df.loc[df['date'] >= "2021-01-29"] 
df
# Out:
#             date    price setcode
# 44    2021-01-29   543.26     KHM
# 45    2021-01-30   527.05     KHM
# 46    2021-01-31   511.39     KHM
# 47    2021-02-01   534.69     KHM
# 48    2021-02-02   530.27     KHM
# ...          ...      ...     ...
# 1063  2023-11-30   280.18     KHM
# 1064  2023-12-01   279.37     KHM
# 1065  2023-12-02   279.15     KHM
# 1066  2023-12-03   278.89     KHM
# 1067  2023-12-04   279.46     KHM
#
# [1024 rows x 3 columns]

# %%
 price =  Path("../Resources/price.db")
con = sqlite3.connect(price)        # conect to price db
cur = con.cursor()

# %%
 for row in df.itertuples():           # else not exist write new data to db 
            insert_sql = f''' INSERT INTO 'goldfish' ('date', 'price', 'setcode') VALUES ('{row[1]}',"{row[2]}",'{row[3]}')'''
            cur.execute(insert_sql)

# %%
con.commit()
